# %% [markdown]
# # Bar Chart Analysis
#
# Subtitle

# %% [markdown]
# In this analysis, we are going to use the data to create graphs that will show us their performance across runs. We will be analyse their average performance, and their performance related to priority levels.

# %%
# imports
from src.database.queries.download_defects import sample_defects_by_group
from src.analysis import gather_player_misses
from src.visualisations.barChart import plot_player_misses

# %%
# download defects data
defects_table_df = sample_defects_by_group(10)

# %%
# calculate misses
player_misses_df = gather_player_misses(defects_table_df)

# %%
# Import the plotting function
plot_player_misses(player_misses_df)

# %% [markdown]
# # TODO some analysis needs to be done
